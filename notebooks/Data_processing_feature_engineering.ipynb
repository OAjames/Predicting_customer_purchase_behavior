# %% [markdown]
# # Updated on 2026‑01‑14: cleaned, portfolio ready

# %% [markdown]
# **1. Imports and Settings**

# %%
import pandas as pd
import numpy as np
from pathlib import Path

pd.set_option("display.max_columns", None)

DATA_PATH = Path(
    "C:/Users/AkanbiOlakunle/Documents/Instacart Market Basket Analysis/instacart-market-basket-analysis"
)

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\AkanbiOlakunle\\Documents\\Instacart Market Basket Analysis\\notebooks'

# %% [markdown]
# **2. Load Prior Data**

# %%
orders = pd.read_csv(DATA_PATH / "orders.csv")
op_prior = pd.read_csv(DATA_PATH / "order_products__prior.csv")
products = pd.read_csv(DATA_PATH / "products.csv")
aisles = pd.read_csv(DATA_PATH / "aisles.csv")
departments = pd.read_csv(DATA_PATH / "departments.csv")

orders_prior = orders[orders["eval_set"] == "prior"]

# %%
# Optimize data types to reduce memory footprint
orders["user_id"] = orders["user_id"].astype("int32")
orders["order_number"] = orders["order_number"].astype("int16")
orders["order_id"] = orders["order_id"].astype("int32")
op_prior["order_id"] = op_prior["order_id"].astype("int32")
op_prior["product_id"] = op_prior["product_id"].astype("int16")
op_prior["add_to_cart_order"] = op_prior["add_to_cart_order"].astype("int8")
op_prior["reordered"] = op_prior["reordered"].astype("int8")
products["product_id"] = products["product_id"].astype("int16")
products["aisle_id"] = products["aisle_id"].astype("int8")
products["department_id"] = products["department_id"].astype("int8")

print("✅ Data types optimized for memory efficiency")
# Out:
# ✅ Data types optimized for memory efficiency

# %%
print(orders.head())
print(orders["eval_set"].unique())
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0
# ['prior' 'train' 'test']

# %% [markdown]
# **3. Merge Prior Orders with Product Metadata**

# %%
prior = (op_prior
    .merge(orders_prior, on="order_id", how="left")
    .merge(products, on="product_id", how="left")
    .merge(aisles, on="aisle_id", how="left")
    .merge(departments, on="department_id", how="left")
)

prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         2      -32416                  1          1   202279    prior
# 1         2       28985                  2          1   202279    prior
# 2         2        9327                  3          0   202279    prior
# 3         2      -19618                  4          1   202279    prior
# 4         2       30035                  5          0   202279    prior
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 0             3          5                  9                     8.0
# 1             3          5                  9                     8.0
# 2             3          5                  9                     8.0
# 3             3          5                  9                     8.0
# 4             3          5                  9                     8.0
#
#             product_name  aisle_id  department_id               aisle  \
# 0     Organic Egg Whites        86             16                eggs
# 1  Michigan Organic Kale        83              4    fresh vegetables
# 2          Garlic Powder       104             13   spices seasonings
# 3         Coconut Butter        19             13       oils vinegars
# 4      Natural Sweetener        17             13  baking ingredients
#
#    department
# 0  dairy eggs
# 1     produce
# 2      pantry
# 3      pantry
# 4      pantry

# %% [markdown]
# **4. Build Time Axis (days_since_first_order)**

# %%
orders_prior_sorted = orders_prior.sort_values(["user_id", "order_number"])
#orders_prior_sorted.head(10)

# %%
orders_prior_sorted["days_since_first_order"] = (
    orders_prior_sorted.groupby("user_id")["days_since_prior_order"].cumsum().fillna(0)
)
#orders_prior_sorted.head()

# %%
prior = prior.merge(
    orders_prior_sorted[["order_id", "days_since_first_order"]],
    on="order_id",
    how="left"
)
#prior.head()

# %%
prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         2      -32416                  1          1   202279    prior
# 1         2       28985                  2          1   202279    prior
# 2         2        9327                  3          0   202279    prior
# 3         2      -19618                  4          1   202279    prior
# 4         2       30035                  5          0   202279    prior
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 0             3          5                  9                     8.0
# 1             3          5                  9                     8.0
# 2             3          5                  9                     8.0
# 3             3          5                  9                     8.0
# 4             3          5                  9                     8.0
#
#             product_name  aisle_id  department_id               aisle  \
# 0     Organic Egg Whites        86             16                eggs
# 1  Michigan Organic Kale        83              4    fresh vegetables
# 2          Garlic Powder       104             13   spices seasonings
# 3         Coconut Butter        19             13       oils vinegars
# 4      Natural Sweetener        17             13  baking ingredients
#
#    department  days_since_first_order
# 0  dairy eggs                    28.0
# 1     produce                    28.0
# 2      pantry                    28.0
# 3      pantry                    28.0
# 4      pantry                    28.0

# %% [markdown]
# **5. Create User-Level Features**
#
# *5.1 Base Aggregates*

# %%
user_orders = orders_prior.groupby("user_id").agg(
    n_orders=("order_number", "max"),
    avg_days_between_orders=("days_since_prior_order", "mean")
)

# %%
user_orders.head()
# Out:
#          n_orders  avg_days_between_orders
# user_id
# 1              10                19.555556
# 2              14                15.230769
# 3              12                12.090909
# 4               5                13.750000
# 5               4                13.333333

# %% [markdown]
# *5.2 Basket Size*

# %%
basket_sizes = (prior.groupby(["user_id", "order_id"])["product_id"]
                .count()
                .groupby("user_id")
                .mean()
                .to_frame("avg_basket_size"))

# %%
basket_sizes.head()
# Out:
#          avg_basket_size
# user_id
# 1               5.900000
# 2              13.928571
# 3               7.333333
# 4               3.600000
# 5               9.250000

# %% [markdown]
# *5.3 Reorder Ratio*

# %%
user_reorder_ratio = (prior.groupby("user_id")["reordered"]
                      .mean()
                      .to_frame("user_reorder_ratio"))

# %%
user_reorder_ratio.head()
# Out:
#          user_reorder_ratio
# user_id
# 1                  0.694915
# 2                  0.476923
# 3                  0.625000
# 4                  0.055556
# 5                  0.378378

# %% [markdown]
# *5.4 Combine Features*

# %%
user_features = (
    user_orders
    .join(basket_sizes, how="left")
    .join(user_reorder_ratio, how="left")
)
user_features.reset_index(inplace=True)

user_features.head()
# Out:
#    user_id  n_orders  avg_days_between_orders  avg_basket_size  \
# 0        1        10                19.555556         5.900000
# 1        2        14                15.230769        13.928571
# 2        3        12                12.090909         7.333333
# 3        4         5                13.750000         3.600000
# 4        5         4                13.333333         9.250000
#
#    user_reorder_ratio
# 0            0.694915
# 1            0.476923
# 2            0.625000
# 3            0.055556
# 4            0.378378

# %% [markdown]
# **6. Create Product-Level Features**

# %%
product_features = (
    prior.groupby(["product_id", "product_name"])
    .agg(
        prod_total_purchases=("order_id", "count"),
        prod_n_users=("user_id", "nunique"),
        prod_reorder_rate=("reordered", "mean"),
        prod_avg_add_to_cart=("add_to_cart_order", "mean"),
    )
    .reset_index()
)


product_features.reset_index(inplace=True)

product_features.head()
# Out:
#    index  product_id                             product_name  \
# 0      0      -32768                             Carrots, Bag
# 1      1      -32767      Organic Biologique Broccoli Florets
# 2      2      -32766      Greek Yogurt Dressing Creamy Ceaser
# 3      3      -32765  Organic Mango Acai Fruit Leather, 12 Ct
# 4      4      -32764                           Shrimp Ceviche
#
#    prod_total_purchases  prod_n_users  prod_reorder_rate  prod_avg_add_to_cart
# 0                   502           294           0.414343             10.358566
# 1                     7             5           0.285714              5.142857
# 2                    14            11           0.214286             12.785714
# 3                   485           150           0.690722              9.828866
# 4                   110            56           0.490909              5.572727

# %% [markdown]
# **7. User–Product Interaction Features**

# %%
up = prior.groupby(["user_id", "product_id"]).agg(
    up_order_count=("order_id", "count"),
    up_first_order_number=("order_number", "min"),
    up_last_order_number=("order_number", "max"),
    up_avg_add_to_cart=("add_to_cart_order", "mean")
)

# %%
up.head()
# Out:
#                     up_order_count  up_first_order_number  \
# user_id product_id
# 1       -29585                   1                     10
#         -26608                   1                     10
#         -25879                   1                     10
#         -23749                   1                      5
#         -19387                   3                      8
#
#                     up_last_order_number  up_avg_add_to_cart
# user_id product_id
# 1       -29585                        10                 7.0
#         -26608                        10                 4.0
#         -25879                        10                 3.0
#         -23749                         5                 7.0
#         -19387                        10                 3.0

# %% [markdown]
# *7.1 Interaction Order Ratio*

# %%
up = up.join(user_features["n_orders"], on="user_id")
up["up_order_ratio"] = up["up_order_count"] / up["n_orders"]

# %% [markdown]
# *7.2 Recency Feature Anchored to Last Order*

# %%
last_day = (prior.groupby(["user_id", "product_id"])["days_since_first_order"]
            .max()
            .to_frame("up_last_days_since_first_order"))

up = up.join(last_day)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[33], line 2
#       1 last_day = (prior.groupby(["user_id", "product_id"])["days_since_first_order"]
# ----> 2             .max()
#       3             .to_frame("up_last_days_since_first_order"))
#       5 up = up.join(last_day)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\groupby\groupby.py:3337, in GroupBy.max(self, numeric_only, min_count, engine, engine_kwargs)
#    3329     return self._numba_agg_general(
#    3330         grouped_min_max,
#    3331         executor.identity_dtype_mapping,
#    (...)   3334         is_max=True,
#    3335     )
#    3336 else:
# -> 3337     return self._agg_general(
#    3338         numeric_only=numeric_only,
#    3339         min_count=min_count,
#    3340         alias="max",
#    3341         npfunc=np.max,
#    3342     )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\groupby\groupby.py:1908, in GroupBy._agg_general(self, numeric_only, min_count, alias, npfunc, **kwargs)
#    1898 @final
#    1899 def _agg_general(
#    1900     self,
#    (...)   1906     **kwargs,
#    1907 ):
# -> 1908     result = self._cython_agg_general(
#    1909         how=alias,
#    1910         alt=npfunc,
#    1911         numeric_only=numeric_only,
#    1912         min_count=min_count,
#    1913         **kwargs,
#    1914     )
#    1915     return result.__finalize__(self.obj, method="groupby")
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\groupby\groupby.py:2005, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    2002     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2003     return result
# -> 2005 new_mgr = data.grouped_reduce(array_func)
#    2006 res = self._wrap_agged_manager(new_mgr)
#    2007 if how in ["idxmin", "idxmax"]:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\internals\base.py:367, in SingleDataManager.grouped_reduce(self, func)
#     365 def grouped_reduce(self, func):
#     366     arr = self.array
# --> 367     res = func(arr)
#     368     index = default_index(len(res))
#     370     mgr = type(self).from_array(res, index)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\groupby\groupby.py:1980, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1978 def array_func(values: ArrayLike) -> ArrayLike:
#    1979     try:
# -> 1980         result = self._grouper._cython_operation(
#    1981             "aggregate",
#    1982             values,
#    1983             how,
#    1984             axis=data.ndim - 1,
#    1985             min_count=min_count,
#    1986             **kwargs,
#    1987         )
#    1988     except NotImplementedError:
#    1989         # generally if we have numeric_only=False
#    1990         # and non-applicable functions
#    1991         # try to python agg
#    1992         # TODO: shouldn't min_count matter?
#    1993         # TODO: avoid special casing SparseArray here
#    1994         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\groupby\ops.py:836, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     831 """
#     832 Returns the values of a cython operation.
#     833 """
#     834 assert kind in ["transform", "aggregate"]
# --> 836 cy_op = WrappedCythonOp(kind=kind, how=how, has_dropped_na=self.has_dropped_na)
#     838 ids, _, _ = self.group_info
#     839 ngroups = self.ngroups
#
# File pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\groupby\ops.py:750, in BaseGrouper.has_dropped_na(self)
#     744 @final
#     745 @cache_readonly
#     746 def has_dropped_na(self) -> bool:
#     747     """
#     748     Whether grouper has null value(s) that are dropped.
#     749     """
# --> 750     return bool((self.group_info[0] < 0).any())
#
# File pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\groupby\ops.py:754, in BaseGrouper.group_info(self)
#     752 @cache_readonly
#     753 def group_info(self) -> tuple[npt.NDArray[np.intp], npt.NDArray[np.intp], int]:
# --> 754     comp_ids, obs_group_ids = self._get_compressed_codes()
#     756     ngroups = len(obs_group_ids)
#     757     comp_ids = ensure_platform_int(comp_ids)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\groupby\ops.py:773, in BaseGrouper._get_compressed_codes(self)
#     767 @final
#     768 def _get_compressed_codes(
#     769     self,
#     770 ) -> tuple[npt.NDArray[np.signedinteger], npt.NDArray[np.intp]]:
#     771     # The first returned ndarray may have any signed integer dtype
#     772     if len(self.groupings) > 1:
# --> 773         group_index = get_group_index(self.codes, self.shape, sort=True, xnull=True)
#     774         return compress_group_index(group_index, sort=self._sort)
#     775         # FIXME: compress_group_index's second return value is int64, not intp
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\groupby\ops.py:699, in BaseGrouper.codes(self)
#     696 @final
#     697 @property
#     698 def codes(self) -> list[npt.NDArray[np.signedinteger]]:
# --> 699     return [ping.codes for ping in self.groupings]
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\groupby\grouper.py:691, in Grouping.codes(self)
#     689 @property
#     690 def codes(self) -> npt.NDArray[np.signedinteger]:
# --> 691     return self._codes_and_uniques[0]
#
# File pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\groupby\grouper.py:835, in Grouping._codes_and_uniques(self)
#     830     uniques = self._uniques
#     831 else:
#     832     # GH35667, replace dropna=False with use_na_sentinel=False
#     833     # error: Incompatible types in assignment (expression has type "Union[
#     834     # ndarray[Any, Any], Index]", variable has type "Categorical")
# --> 835     codes, uniques = algorithms.factorize(  # type: ignore[assignment]
#     836         self.grouping_vector, sort=self._sort, use_na_sentinel=self._dropna
#     837     )
#     838 return codes, uniques
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\algorithms.py:795, in factorize(values, sort, use_na_sentinel, size_hint)
#     792             # Don't modify (potentially user-provided) array
#     793             values = np.where(null_mask, na_value, values)
# --> 795     codes, uniques = factorize_array(
#     796         values,
#     797         use_na_sentinel=use_na_sentinel,
#     798         size_hint=size_hint,
#     799     )
#     801 if sort and len(uniques) > 0:
#     802     uniques, codes = safe_sort(
#     803         uniques,
#     804         codes,
#    (...)    807         verify=False,
#     808     )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\algorithms.py:595, in factorize_array(values, use_na_sentinel, size_hint, na_value, mask)
#     592 hash_klass, values = _get_hashtable_algo(values)
#     594 table = hash_klass(size_hint or len(values))
# --> 595 uniques, codes = table.factorize(
#     596     values,
#     597     na_sentinel=-1,
#     598     na_value=na_value,
#     599     mask=mask,
#     600     ignore_na=use_na_sentinel,
#     601 )
#     603 # re-cast e.g. i8->dt64/td64, uint8->bool
#     604 uniques = _reconstruct_data(uniques, original.dtype, original)
#
# File pandas/_libs/hashtable_class_helper.pxi:2976, in pandas._libs.hashtable.Int64HashTable.factorize()
#
# File pandas/_libs/hashtable_class_helper.pxi:2811, in pandas._libs.hashtable.Int64HashTable._unique()
#
# MemoryError: Unable to allocate 247. MiB for an array with shape (32434489,) and data type int64

# %% [markdown]
# **8. Save Features**

# %%
# New folder inside current project
features_dir = Path("./my_data/features")
features_dir.mkdir(parents=True, exist_ok=True)
user_features.to_parquet(features_dir / "user_features.parquet", engine="fastparquet")
product_features.to_parquet(
    features_dir / "product_features.parquet", engine="fastparquet"
)
up.reset_index().to_parquet(
    features_dir / "user_product_features.parquet", engine="fastparquet"
)
prior.to_parquet("my_data/features/prior_merged.parquet", engine="fastparquet")

# %%
# Read a Parquet file
ftt = pd.read_parquet("my_data/features/user_features.parquet", engine="fastparquet")
print(ftt.head())
# Out:
#    user_id  n_orders  avg_days_between_orders  avg_basket_size  \
# 0        1        10                19.555556         5.900000
# 1        2        14                15.230769        13.928571
# 2        3        12                12.090909         7.333333
# 3        4         5                13.750000         3.600000
# 4        5         4                13.333333         9.250000
#
#    user_reorder_ratio
# 0            0.694915
# 1            0.476923
# 2            0.625000
# 3            0.055556
# 4            0.378378

# %%
# ---------------------------------------------------
# FINAL INFERENCE FEATURE TABLE (TRAIN / SERVE PARITY)
# ---------------------------------------------------

import gc

model_features = [
    "n_orders_x",
    "avg_days_between_orders",
    "avg_basket_size",
    "user_reorder_ratio",
    "prod_total_purchases",
    "prod_n_users",
    "prod_reorder_rate",
    "prod_avg_add_to_cart",
    "up_order_count",
    "up_first_order_number",
    "up_last_order_number",
    "up_avg_add_to_cart",
    "n_orders_y",
    "up_order_ratio",
    "up_last_days_since_first_order",
]

# Reset index without deep copy + force garbage collection
up_reset = up.reset_index(drop=False)
del up
gc.collect()

# Merge step by step with memory management
print("Merging user features...")
final_features = up_reset.merge(user_features, on="user_id", how="left")
del up_reset
gc.collect()

print("Merging product features...")
final_features = final_features.merge(product_features, on="product_id", how="left")
gc.collect()

# Sanity check
missing = set(model_features) - set(final_features.columns)
assert not missing, f"Missing features: {missing}"

# Select columns directly without copy to avoid memory overhead
# Write directly to parquet with index=False
inference_features = final_features[
    ["user_id", "product_id", "product_name"] + model_features
]

del final_features
gc.collect()

inference_features.to_parquet(
    "./my_data/features/inference_features.parquet", index=False
)

print("✅ inference_features.parquet saved with full model feature set")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 26
#       7 model_features = [
#       8     "n_orders_x",
#       9     "avg_days_between_orders",
#    (...)     22     "up_last_days_since_first_order",
#      23 ]
#      25 # Reset index without deep copy + force garbage collection
# ---> 26 up_reset = up.reset_index(drop=False)
#      27 del up
#      28 gc.collect()
#
# NameError: name 'up' is not defined
